% %% [markdown]
% # Questo è un notebook di Jupyter con Octave (Matlab)
%
% Questa è un *problema di Neumann-Dini* del cavolo che ci ha detto la Pandolfi, anche se continua a sbagliare a scrivere le cose alla lavagna:
%
% $$\begin{cases} \nabla^2 \psi_g (y,z) = 0 & in\ A \\ \frac{\partial \psi_g}{\partial n} = zn_y - yn_z & su\ \Gamma \end{cases}$$

% %%
x = [1:0.1:10];

% %%
y = @(x) x.^2
% Out:
% y =
%
% @(x) x .^ 2

% %%
plot(x,y(x))

% %%
A = [1 2 3;
    4 5 6;
    10 23 0]
% Out:
% A =
%
%     1    2    3
%     4    5    6
%    10   23    0

% %%
B= A'
% Out:
% B =
%
%     1    4   10
%     2    5   23
%     3    6    0

% %%
pkg load all

% %%
sys = tf([1 10],[1 -5 3])
% Out:
% Transfer function 'sys' from input 'u1' to output ...
%
%          s + 10
%  y1:  -------------
%       s^2 - 5 s + 3
%
% Continuous-time model.

% %%
pzmap(sys)
